# %% [markdown]
# <a href="https://colab.research.google.com/github/shruvie/Data-Visualization-Plots-Notebook/blob/main/Untitled29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install sweetviz
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 27.2 MB/s eta 0:00:00
# ...

# %%
import sweetviz as sv
import pandas as pd

# Ensure sweetviz is installed
try:
    import sweetviz
except ImportError:
    print("sweetviz not found, installing...")
    # !pip install sweetviz --quiet
    import sweetviz

# Assuming 'df' DataFrame is already loaded and available from previous cells.
# If 'df' is not defined, you might need to run data loading cells first (e.g., `210a85c9`, `c75ffb05`).

if 'df' in locals():
    print("Generating Sweetviz report for the DataFrame 'df'...")

    # Analyze the DataFrame
    sweetviz_report = sv.analyze(df)

    # Display the report interactively in the notebook
    print("\n✅ Sweetviz report generated successfully! Displaying in notebook...")
    sweetviz_report.show_notebook()
else:
    print("Error: DataFrame 'df' is not available. Please ensure it's loaded before running Sweetviz.")
# Out:
# Error: DataFrame 'df' is not available. Please ensure it's loaded before running Sweetviz.
